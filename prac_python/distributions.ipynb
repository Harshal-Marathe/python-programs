# %%
import numpy.random as nr
import scipy.stats as ss
import matplotlib.pyplot as plt
import numpy as np

# %%
loc,scale,size=30,2,50
nr.normal(loc,scale,size)
# Out:
# array([29.30532877, 30.4592491 , 28.5733151 , 31.31147441, 32.02475689,
#        26.08167642, 30.924531  , 26.72192236, 26.71267874, 27.81852905,
#        32.23587772, 27.50876412, 27.57274627, 30.41560879, 28.71136605,
#        33.82135509, 29.44888645, 30.39215956, 27.15470368, 27.41477576,
#        28.76372207, 31.22098526, 27.52093153, 29.46248182, 28.79058267,
#        27.82978757, 28.19083272, 28.51273768, 27.3824007 , 30.78362817,
#        25.79249047, 32.3805186 , 32.5497224 , 31.75824818, 29.82611468,
#        30.98829814, 30.84567623, 31.8297855 , 30.16321577, 31.83925819,
#        28.77570069, 28.18376301, 28.64440833, 32.91235697, 31.38601318,
#        27.13523498, 27.05218104, 30.00542891, 31.81924485, 31.02609205])

# %%
loc,scale,size=30,2,(1000,5)
df=nr.normal(loc,scale,size)
print(df)
# Out:
# [[29.49860496 32.83626748 26.01069431 30.08764583 27.81921752]
#  [31.49678396 31.58792046 28.21204245 28.11104272 31.41933658]
#  [29.27885497 25.10801949 30.28968542 31.55599523 29.39170292]
#  ...
#  [31.85791275 31.33722403 29.26357246 25.65192109 30.44974484]
#  [29.30650591 30.45464965 32.0150523  30.06133557 33.7524772 ]
#  [31.56359252 32.30946059 27.74557015 26.69148941 28.84993054]]

# %%
sum(df.T)
# Out:
# array([146.25243009, 150.82712618, 145.62425803, 144.4489712 ,
#        162.4130619 , 153.05874855, 153.70819537, 150.76084836,
#        151.23891585, 156.42006505, 156.10377414, 159.11100501,
#        155.94712902, 146.01241647, 146.5644814 , 153.18991906,
#        147.04705624, 155.40462554, 155.32060158, 152.69181714,
#        154.72147521, 151.28540584, 142.12186461, 155.38713225,
#        152.91808819, 151.91128836, 153.84057945, 147.23494543,
#        147.27686378, 148.56024278, 152.16247842, 151.27227882,
#        140.80225865, 147.30462776, 156.94444008, 151.20489668,
#        151.7796398 , 154.40481268, 150.75683325, 154.69959551,
#        153.65875228, 155.15683517, 149.37382467, 151.78341077,
#        149.07967242, 149.82376604, 144.65476616, 152.70741566,
#        149.65739578, 149.76472772, 151.71223393, 148.5019297 ,
#        144.02673635, 151.22049651, 150.59504695, 154.55260885,
#        153.70998602, 147.25841676, 143.46579399, 146.58596929,
# ...

# %%
loc,scale,size=30,2,100
df1=nr.normal(loc,scale,size)
print(df1)
# Out:
# [30.39100473 30.82712375 27.53634177 30.82722303 30.27046833 30.16623044
#  30.21641378 33.61020609 33.66318616 33.38894392 24.59824449 29.694957
#  29.74117477 29.82864481 27.68504042 25.64851272 28.56979603 28.18630479
#  29.77201497 31.19493337 28.21785143 28.75685105 28.04067479 29.45217115
#  33.25926483 29.71363355 29.22155612 31.29459737 29.61181757 28.73334777
#  27.38294208 30.61219619 29.45215901 27.39829942 31.63873703 31.80720871
#  28.88679371 30.50112315 28.71701925 28.59386415 31.48730673 30.9540547
#  31.13802301 27.48372996 29.38104341 27.97500731 27.9886996  27.76301126
#  30.48400424 29.25758277 27.86564528 28.79037886 26.38017398 30.11261595
#  36.14797785 31.55943921 32.0215554  27.39981361 30.13503992 28.11560783
#  27.36055995 27.46839884 27.97258278 27.84363824 30.70065203 28.82762404
#  30.4336486  28.65792081 33.35348117 32.05891501 29.91562044 29.34985637
#  32.69497888 29.77699149 31.94108012 31.49899409 28.51155161 27.77076425
# ...

# %%
plt.hist(df1)
# Out:
# (array([ 2.,  2., 21., 15., 27., 17.,  8.,  7.,  0.,  1.]),
#  array([24.59824449, 25.75321783, 26.90819117, 28.0631645 , 29.21813784,
#         30.37311117, 31.52808451, 32.68305784, 33.83803118, 34.99300452,
#         36.14797785]),
#  <BarContainer object of 10 artists>)

# %%
n,p,size=10,0.8,100
df2=nr.binomial(n,p,size)

# %%
plt.bar(df2,bins=11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.bar(df2,bins=11)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
ss.norm.rvs(loc=10,scale=2,size=(4,2))
# Out:
# array([[ 8.76972966,  8.83279015],
#        [12.88526491,  8.39237546],
#        [ 7.81932383, 11.35808025],
#        [10.41568508,  9.92928702]])

# %%
x=np.linspace(-3,3,100)
df5=ss.norm.pdf(x,1)
plt.hist(df5)
# Out:
# (array([31., 10.,  8.,  6.,  6.,  6.,  6.,  4.,  8., 15.]),
#  array([1.33830226e-04, 4.00146752e-02, 7.98955203e-02, 1.19776365e-01,
#         1.59657210e-01, 1.99538055e-01, 2.39418900e-01, 2.79299745e-01,
#         3.19180590e-01, 3.59061435e-01, 3.98942280e-01]),
#  <BarContainer object of 10 artists>)

# %%
x=np.linspace(0,10,50)
d=ss.expon.pdf(x, scale=1)
plt.plot(d)

# %%
d1=ss.gamma.pdf(x, 5, scale=1)
plt.v(d1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 2
#       1 d1=ss.gamma.pdf(x, 5, scale=1)
# ----> 2 plt.violin(d1)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'violin'

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
